# %% [markdown]
# ## Data Pre-processing (Part - 1)

# %%
import pandas as pd

# %%
df = pd.read_csv(r'50_Startups.csv')

# %%
df.shape
# Out:
# (50, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        48 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  47 non-null     float64
#  3   Profit           50 non-null     float64
# dtypes: float64(4)
# memory usage: 1.7 KB

# %%
df.isnull().sum()
# Out:
# R&D Spend          2
# Administration     0
# Marketing Spend    3
# Profit             0
# dtype: int64

# %%
df.fillna(df.mean(), inplace=True)

# %%
df
# Out:
#         R&D Spend  Administration  Marketing Spend     Profit
# 0   165349.200000       136897.80    471784.100000  192261.83
# 1   162597.700000       151377.59    443898.530000  191792.06
# 2   153441.510000       101145.55    407934.540000  191050.39
# 3   144372.410000       118671.85    383199.620000  182901.99
# 4   142107.340000        91391.77    366168.420000  166187.94
# 5   131876.900000        99814.71    362861.360000  156991.12
# 6   134615.460000       147198.87    127716.820000  156122.51
# 7   130298.130000       145530.06    323876.680000  155752.60
# 8   120542.520000       148718.95    311613.290000  152211.77
# 9   123334.880000       108679.17    304981.620000  149759.96
# 10  101913.080000       110594.11    229160.950000  146121.95
# 11  100671.960000        91790.61    249744.550000  144259.40
# 12   93863.750000       127320.38    249839.440000  141585.52
# 13   91992.390000       135495.07    252664.930000  134307.35
# 14  119943.240000       156547.42    256512.920000  132602.65
# 15  114523.610000       122616.84    261776.230000  129917.04
# 16   78013.110000       121597.55    264346.060000  126992.93
# 17   94657.160000       145077.58    282574.310000  125370.37
# 18   91749.160000       114175.79    294919.570000  124266.90
# 19   86419.700000       153514.11    224494.784894  122776.86
# 20   76253.860000       113867.30    298664.470000  118474.03
# 21   78389.470000       153773.43    299737.290000  111313.02
# 22   73994.560000       122782.75    303319.260000  110352.25
# 23   67532.530000       105751.03    304768.730000  108733.99
# 24   77044.010000        99281.34    140574.810000  108552.04
# 25   64664.710000       139553.16    137962.620000  107404.34
# 26   75328.870000       144135.98    134050.070000  105733.54
# 27   72107.600000       127864.55    353183.810000  105008.31
# 28   66051.520000       182645.56    118148.200000  103282.38
# 29   65605.480000       153032.06    107138.380000  101004.64
# 30   61994.480000       115641.28     91131.240000   99937.59
# 31   61136.380000       152701.92     88218.230000   97483.56
# 32   63408.860000       129219.61     46085.250000   97427.84
# 33   55493.950000       103057.49    214634.810000   96778.92
# 34   46426.070000       157693.92    210797.670000   96712.80
# 35   46014.020000        85047.44    205517.640000   96479.51
# 36   28663.760000       127056.21    201126.820000   90708.19
# 37   44069.950000        51283.14    197029.420000   89949.14
# 38   20229.590000        65947.93    185265.100000   81229.06
# 39   38558.510000        82982.09    174999.300000   81005.76
# 40   28754.330000       118546.05    172795.670000   78239.91
# 41   27892.920000        84710.77    164470.710000   77798.83
# 42   23640.930000        96189.63    148001.110000   71498.49
# 43   15505.730000       127382.30     35534.170000   69758.98
# 44   22177.740000       154806.14     28334.720000   65200.33
# 45    1000.230000       124153.04      1903.930000   64926.08
# 46    1315.460000       115816.21    297114.460000   49490.75
# 47   76793.349583       135426.92    224494.784894   42559.73
# 48     542.050000        51743.15    224494.784894   35673.41
# 49   76793.349583       116983.80     45173.060000   14681.40

# %% [markdown]
# ## Data Visualization (Part - 2)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['R&D Spend'], kde=True, color='blue', bins=20)
plt.title("Distribution of R&D Spend")
plt.xlabel("R&D Spend")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Administration'], kde=True, color='green', bins=20)
plt.title("Distribution of Administration")
plt.xlabel("Administration")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Marketing Spend'], kde=True, color='purple', bins=20)
plt.title("Distribution of Marketing Spend")
plt.xlabel("Marketing Spend")
plt.ylabel("Frequency")
plt.show()

# %%
sns.lineplot(x=df['Administration'], y=df['Profit'], data=df)
plt.show()

# %%
sns.lineplot(x=df['Marketing Spend'], y=df['Profit'], data=df)
plt.show()

# %%
sns.lineplot(x=df['R&D Spend'], y=df['Profit'], data=df)
plt.show()

# %%
sns.boxplot(x=df['Profit'], data=df)
plt.show()

# %%
plt.boxplot(df['Profit'])
plt.show()

# %% [markdown]
# ### Dealing with outliers (Part 3)

# %%
import numpy as np

# %%
# Need to create a boxplot to study the position of the outliers
plt.boxplot(df['Profit'])
plt.title("Boxplot of 'Profit' with Outliers", color='green', fontsize=20)
plt.show()

#Using IQR Method
Q1 = df['Profit'].quantile(0.25)
Q3 = df['Profit'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)
median_value = df['Profit'].median()

outliers = df[(df['Profit'] > upper_bound) | (df['Profit'] < lower_bound)]
print('\nNumber of Outliers: ', len(outliers),"\n")

# Replacing the outliers with the IQR Median values
df['Profit'] = np.where((df['Profit'] < lower_bound) | (df['Profit'] > upper_bound), median_value, df['Profit'])

# To Study the difference in the Boxplots before & After
plt.boxplot(df['Profit'])
plt.title("Boxplot of 'Profit' after replacing Outliers", color='green', fontsize=20)
plt.show()
# Out:
# Number of Outliers:  1

# %%
# To convert strings into numeric values
from sklearn import preprocessing

# By Label Encoding
le = preprocessing.LabelEncoder()
for column in df.columns:
    if df[column].dtype == object:
        df[column] = le.fit_transform(df[column])

# %%
continuous_cols = df.select_dtypes(include=np.number).columns

# Applying Log Transformation to all continuous or numeric columns=
df[continuous_cols] = np.log1p(df[continuous_cols])
df[continuous_cols]
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit
# 0   12.015821       11.826997        13.064279  12.166619
# 1   11.999040       11.927539        13.003354  12.164172
# 2   11.941081       11.524326        12.918864  12.160298
# 3   11.880158       11.684126        12.856314  12.116711
# 4   11.864345       11.422922        12.810851  12.020881
# 5   11.789632       11.511081        12.801779  11.963951
# 6   11.810185       11.899547        11.757579  11.958403
# 7   11.777588       11.888145        12.688121  11.956031
# 8   11.699766       11.909820        12.649521  11.933035
# 9   11.722667       11.596165        12.628010  11.916796
# 10  11.531885       11.613631        12.342184  11.892204
# 11  11.519633       11.427276        12.428198  11.879375
# 12  11.449610       11.754470        12.428578  11.860666
# 13  11.429472       11.816698        12.439823  11.807894
# 14  11.694782       11.961121        12.454938  11.795120
# 15  11.648545       11.716828        12.475249  11.774659
# 16  11.264645       11.708480        12.485018  11.751895
# 17  11.458027       11.885031        12.551700  11.739036
# 18  11.426825       11.645503        12.594461  11.730195
# 19  11.366983       11.941554        12.321612  11.718132
# 20  11.241836       11.642798        12.607079  11.682458
# 21  11.269458       11.943242        12.610665  11.620110
# 22  11.211760       11.718180        12.622544  11.611442
# 23  11.120379       11.568852        12.627312  11.596669
# 24  11.252145       11.505723        11.853502  11.594994
# 25  11.076986       11.846208        11.834745  11.584365
# 26  11.229632       11.878519        11.805976  11.568687
# 27  11.185929       11.758735        12.774747  11.561804
# 28  11.098205       12.115308        11.679704  11.545232
# 29  11.091430       11.938409        11.581886  11.522932
# 30  11.034817       11.658257        11.420067  11.512311
# 31  11.020879       11.936250        11.387580  11.487449
# 32  11.057375       11.769276        10.738270  11.486878
# 33  10.924047       11.543052        12.276698  11.480195
# 34  10.745638       11.968418        12.258659  11.479511
# 35  10.736723       11.350976        12.233292  11.477096
# 36  10.263424       11.752393        12.211696  11.415414
# 37  10.693556       10.845137        12.191113  11.407011
# 38   9.914951       11.096636        12.129548  11.305041
# 39  10.559958       11.326392        12.072543  11.302288
# 40  10.266578       11.683065        12.059871  11.267548
# 41  10.236164       11.347010        12.010494  11.261895
# 42  10.070777       11.474087        11.904982  11.177446
# 43   9.649029       11.754956        10.478278  11.152816
# 44  10.006889       11.949935        10.251878  11.085235
# 45   6.908985       11.729278         7.552201  11.081020
# 46   7.182702       11.659768        12.601876  10.809561
# 47  11.248886       11.816195        12.321612  10.658687
# 48   6.297201       10.854067        12.321612  10.482189
# 49  11.248886       11.669799        10.718278  11.589694

# %%
# To Study the correlation between the columns using this heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True)
plt.title('Heatmap to find Correlation between the columns', fontsize=30, color='green')
plt.xticks(color='green')
plt.yticks(color='green')
plt.show()

# %%
# Identifying High Correlation Matrix Values
corr_matrix = df.corr().abs()
high_corr = np.where(corr_matrix > 0.7)
high_corr = [(corr_matrix.columns[x], corr_matrix.columns[y]) for x, y in zip(*high_corr) if x != y and x < y]
print(high_corr)
# Out:
# [('R&D Spend', 'Profit')]

# %%
from sklearn.model_selection import train_test_split

# Taking 'y' as our target column - 'amount_in_USD'
y = df['Profit']

# Rest all columns to be considered as 'x'
x = df[["R&D Spend", "Administration", "Marketing Spend"]]

# Splitting our dataset into Training & Testing Data with 80:20 Ratio
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 42)
print(len(x_train))
print(len(x_test))
# Out:
# 40
# 10

# %%
from sklearn.linear_model import LinearRegression
linear = LinearRegression()

# %%
# Training the model
linear.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Calculating Training & Testing Accuracies
print(linear.score(x_train, y_train))
print(linear.score(x_test, y_test))
# Out:
# 0.6928005013559985
# -0.19049145198669737

# %%
from sklearn.tree import DecisionTreeRegressor
decision = DecisionTreeRegressor()

# %%
# Training the model
decision.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
# Calculating Training & Testing Accuracies
print(decision.score(x_train, y_train))
print(decision.score(x_test, y_test))
# Out:
# 1.0
# 0.8517313145832539

# %%
from sklearn.ensemble import RandomForestRegressor
random = RandomForestRegressor()

# %%
random.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# Calculating Training & Testing Accuracies
print(random.score(x_train, y_train))
print(random.score(x_test, y_test))
# Out:
# 0.9626312915585289
# 0.7597646148556008

# %%
from sklearn.ensemble import AdaBoostRegressor
ada = AdaBoostRegressor()

# %%
# Training the Model
ada.fit(x_train, y_train)
# Out:
# AdaBoostRegressor()

# %%
# Calculating Training & Testing Accuracies
print(ada.score(x_train, y_train))
print(ada.score(x_test, y_test))
# Out:
# 0.9784213747457258
# 0.9008752513689899

# %%
import xgboost
xg = xgboost.XGBRegressor()

# %%
# Training the model
xg.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Calculating Training & Testing Accuracies
print(xg.score(x_train, y_train))
print(xg.score(x_test, y_test))
# Out:
# 0.9999932353933291
# 0.6859087613747707

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
# Testing the model - Linear Regression
linear_y_pred = linear.predict(x_test)

# Evaluating MSE
mse_lr = mean_squared_error(y_test, linear_y_pred)
# Evaluating RMSE
rmse_lr = np.sqrt(mse_lr)
# Evaluating MAE
mae_lr = mean_absolute_error(y_test, linear_y_pred)
# Evaluating R-SQUARE
r2_lr = r2_score(y_test, linear_y_pred)

print('MSE = ', mse_lr)
print('RMSE = ', rmse_lr)
print('MAE = ', mae_lr)
print('R-Square = ', r2_lr)
# Out:
# MSE =  0.16795609012216642
# RMSE =  0.4098244625716801
# MAE =  0.1853135290181541
# R-Square =  -0.19049145198669737

# %%
# Testing the model
decision_y_pred = decision.predict(x_test)

# Evaluating MSE
mse_dt = mean_squared_error(decision_y_pred, y_test)
# Evaluating RMSE
rmse_dt = np.sqrt(mse_dt)
# Evaluating MAE
mae_dt = mean_absolute_error(decision_y_pred, y_test)
# Evaluating R-SQUARE
r2_dt = r2_score(decision_y_pred, y_test)

print('MSE = ', mse_dt)
print('RMSE = ', rmse_dt)
print('MAE = ', mae_dt)
print('R-Square = ', r2_dt)
# Out:
# MSE =  0.020917939938663584
# RMSE =  0.1446303562142595
# MAE =  0.09883198131852336
# R-Square =  0.8268335536325125

# %%
# Testing the model
random_y_pred = random.predict(x_test)

# Evaluating MSE
mse_rf = mean_squared_error(y_test, random_y_pred)
# Evaluating RMSE
rmse_rf = np.sqrt(mse_rf)
# Evaluating MAE
mae_rf = mean_absolute_error(y_test, random_y_pred)
# Evaluating R-SQAURE
r2_rf = r2_score(y_test, random_y_pred)

print('MSE = ', mse_rf)
print('RMSE = ', rmse_rf)
print('MAE = ', mae_rf)
print('R-Square = ', r2_rf)
# Out:
# MSE =  0.03389272214471721
# RMSE =  0.18409976139234188
# MAE =  0.10141043489289406
# R-Square =  0.7597646148556008

# %%
# Testing the model
ada_y_pred = ada.predict(x_test)

# Evaluating MSE
mse_ad = mean_squared_error(y_test, ada_y_pred)
# Evaluating RMSE
rmse_ad = np.sqrt(mse_ad)
# Evaluating MAE
mae_ad = mean_absolute_error(y_test, ada_y_pred)
# Evaluating R-SQAURE
r2_ad = r2_score(y_test, ada_y_pred)

print('MSE = ', mse_ad)
print('RMSE = ', rmse_ad)
print('MAE = ', mae_ad)
print('R-Square = ', r2_ad)
# Out:
# MSE =  0.013984649101531766
# RMSE =  0.11825670848426217
# MAE =  0.07130177582065703
# R-Square =  0.9008752513689899

# %%
# Testing the model
xg_y_pred = xg.predict(x_test)

# Evaluating MSE
mse_xg = mean_squared_error(y_test, xg_y_pred)
# Evaluating RMSE
rmse_xg = np.sqrt(mse_xg)
# Evaluating MAE
mae_xg = mean_absolute_error(y_test, xg_y_pred)
# Evaluating R-SQAURE
r2_xg = r2_score(y_test, xg_y_pred)

print('MSE = ', mse_xg)
print('RMSE = ', rmse_xg)
print('MAE = ', mae_xg)
print('R-Square = ', r2_xg)
# Out:
# MSE =  0.0443124024898176
# RMSE =  0.21050511274032657
# MAE =  0.11511037712033936
# R-Square =  0.6859087613747707

# %%
# Mapping all Model Evaluations into a Table

labels = ['Linear Regression', 'Decision Tree', 'Random Forest', 'AdaBoost', 'XGBoost']
mse_values = [mse_lr, mse_dt, mse_rf, mse_ad, mse_xg]
rmse_values = [rmse_lr, rmse_dt, rmse_rf, rmse_ad, rmse_xg]
mae_values = [mae_lr, mae_dt, mae_rf, mae_ad, mae_xg]
r2_values = [r2_lr, r2_dt, r2_rf, r2_ad, r2_xg]

data = {
    'Model': labels,
    'MSE': mse_values,
    'RMSE': rmse_values,
    'MAE': mae_values,
    'R-Squared': r2_values
}

df_val = pd.DataFrame(data)
df_val.set_index('Model', inplace=True)
df_val
# Out:
#                         MSE      RMSE       MAE  R-Squared
# Model
# Linear Regression  0.167956  0.409824  0.185314  -0.190491
# Decision Tree      0.020918  0.144630  0.098832   0.826834
# Random Forest      0.033893  0.184100  0.101410   0.759765
# AdaBoost           0.013985  0.118257  0.071302   0.900875
# XGBoost            0.044312  0.210505  0.115110   0.685909

# %%
print(max(r2_values))
# Out:
# 0.9008752513689899
